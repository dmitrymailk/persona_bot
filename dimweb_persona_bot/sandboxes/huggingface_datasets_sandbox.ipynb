# %% [markdown]
# # What if my dataset isn't on the Hub?

# %%
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-train.json.gz
# !wget https://github.com/crux82/squad-it/raw/master/SQuAD_it-test.json.gz

# %%
# !gzip -dkv ./datasets/en_squad/SQuAD_it-*.json.gz
# Out:
# ./datasets/en_squad/SQuAD_it-test.json.gz:	 87.5% -- created ./datasets/en_squad/SQuAD_it-test.json
# ./datasets/en_squad/SQuAD_it-train.json.gz:	 82.3% -- created ./datasets/en_squad/SQuAD_it-train.json

# %%
from datasets import load_dataset

squad_it_dataset = load_dataset("json", data_files="./datasets/it_squad/SQuAD_it-train.json", field="data")
# Out:
# Using custom data configuration default-e5ea4ca9a74719c6
# Found cached dataset json (/home/kosenko/.cache/huggingface/datasets/json/default-e5ea4ca9a74719c6/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab)
# A Jupyter Widget

# %%
squad_it_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
# })

# %%
squad_it_dataset["train"][0]
# Out:
# {'title': 'Terremoto del Sichuan del 2008',
#  'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
data_files = {"train": "./datasets/it_squad/SQuAD_it-train.json", "test": "./datasets/it_squad/SQuAD_it-test.json"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")
squad_it_dataset
# Out:
# Using custom data configuration default-e32308063aef53c3
# Found cached dataset json (/home/kosenko/.cache/huggingface/datasets/json/default-e32308063aef53c3/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab)
# A Jupyter Widget
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 442
#     })
#     test: Dataset({
#         features: ['title', 'paragraphs'],
#         num_rows: 48
#     })
# })

# %%
data_files = {"train": "./datasets/it_squad/SQuAD_it-train.json.gz", "test": "./datasets/it_squad/SQuAD_it-test.json.gz"}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")

# %%
url = "https://github.com/crux82/squad-it/raw/master/"
data_files = {
    "train": url + "SQuAD_it-train.json.gz",
    "test": url + "SQuAD_it-test.json.gz",
}
squad_it_dataset = load_dataset("json", data_files=data_files, field="data")

# %% [markdown]
# # Time to slice and dice

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip"
# Out:
# --2022-12-23 20:36:27--  https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42989872 (41M) [application/x-httpd-php]
# Saving to: ‘drugsCom_raw.zip’
#
# drugsCom_raw.zip    100%[===================>]  41.00M  12.7MB/s    in 3.2s
#
# 2022-12-23 20:36:31 (12.7 MB/s) - ‘drugsCom_raw.zip’ saved [42989872/42989872]

# %%
# !unzip ./datasets/drugsCom_raw/drugsCom_raw.zip
# Out:
# Archive:  ./datasets/drugsCom_raw/drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %%
from datasets import load_dataset

data_files = {
    "train": "./datasets/drugsCom_raw/drugsComTrain_raw.tsv", 
    "test": "./datasets/drugsCom_raw/drugsComTest_raw.tsv"
}
# \t is the tab character in Python
drug_dataset = load_dataset("csv", data_files=data_files, delimiter="\t")
# Out:
# Using custom data configuration default-870720e81f127769
# ...
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# Dataset csv downloaded and prepared to /home/kosenko/.cache/huggingface/datasets/csv/default-870720e81f127769/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
# A Jupyter Widget

# %%
drug_sample = drug_dataset["train"].shuffle(seed=42).select(range(1000))
# Peek at the first few examples
drug_sample[:3]
# Out:
# {'Unnamed: 0': [87571, 178045, 80482],
#  'drugName': ['Naproxen', 'Duloxetine', 'Mobic'],
#  'condition': ['Gout, Acute', 'ibromyalgia', 'Inflammatory Conditions'],
#  'review': ['"like the previous person mention, I&#039;m a strong believer of aleve, it works faster for my gout than the prescription meds I take. No more going to the doctor for refills.....Aleve works!"',
#   '"I have taken Cymbalta for about a year and a half for fibromyalgia pain. It is great\r\nas a pain reducer and an anti-depressant, however, the side effects outweighed \r\nany benefit I got from it. I had trouble with restlessness, being tired constantly,\r\ndizziness, dry mouth, numbness and tingling in my feet, and horrible sweating. I am\r\nbeing weaned off of it now. Went from 60 mg to 30mg and now to 15 mg. I will be\r\noff completely in about a week. The fibro pain is coming back, but I would rather deal with it than the side effects."',
# ...

# %%
for split in drug_dataset.keys():
    assert len(drug_dataset[split]) == len(drug_dataset[split].unique("Unnamed: 0"))

# %%
drug_dataset = drug_dataset.rename_column(
    original_column_name="Unnamed: 0", new_column_name="patient_id"
)
drug_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 161297
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount'],
#         num_rows: 53766
#     })
# })

# %%
def lowercase_condition(example):
    return {"condition": example["condition"].lower()}


drug_dataset.map(lowercase_condition)
# Out:
# A Jupyter Widget
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [24], line 5
#       1 def lowercase_condition(example):
#       2     return {"condition": example["condition"].lower()}
# ----> 5 drug_dataset.map(lowercase_condition)
#
# File ~/env/lib/python3.8/site-packages/datasets/dataset_dict.py:777, in map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     767 if cache_file_names is None:
#     768     cache_file_names = {k: None for k in self}
#     769 return DatasetDict(
#     770     {
#     771         k: dataset.map(
#     772             function=function,
#     773             with_indices=with_indices,
#     774             with_rank=with_rank,
# ...

# %%
def filter_nones(x):
    return x["condition"] is not None

# %%
drug_dataset = drug_dataset.filter(filter_nones)
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %%
drug_dataset = drug_dataset.map(lowercase_condition)
# Check that lowercasing worked
drug_dataset["train"]["condition"][:3]
# Out:
# A Jupyter Widget
# A Jupyter Widget
# ['left ventricular dysfunction', 'adhd', 'birth control']

# %%
def compute_review_length(example):
    return {"review_length": len(example["review"].split())}

drug_dataset = drug_dataset.map(compute_review_length)
# Inspect the first training example
drug_dataset["train"][0]
# Out:
# A Jupyter Widget
# A Jupyter Widget
# {'patient_id': 206461,
#  'drugName': 'Valsartan',
#  'condition': 'left ventricular dysfunction',
#  'review': '"It has no side effect, I take it in combination of Bystolic 5 Mg and Fish Oil"',
#  'rating': 9.0,
#  'date': 'May 20, 2012',
#  'usefulCount': 27,
#  'review_length': 17}

# %%
drug_dataset["train"].sort("review_length")[:3]
# Out:
# {'patient_id': [103488, 23627, 20558],
#  'drugName': ['Loestrin 21 1 / 20', 'Chlorzoxazone', 'Nucynta'],
#  'condition': ['birth control', 'muscle spasm', 'pain'],
#  'review': ['"Excellent."', '"useless"', '"ok"'],
#  'rating': [10.0, 1.0, 6.0],
#  'date': ['November 4, 2008', 'March 24, 2017', 'August 20, 2016'],
#  'usefulCount': [5, 2, 10],
#  'review_length': [1, 1, 1]}

# %%
import html

text = "I&#039;m a transformer called BERT"
html.unescape(text)
# Out:
# "I'm a transformer called BERT"

# %%
drug_dataset = drug_dataset.map(lambda x: {"review": html.unescape(x["review"])})
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %%
new_drug_dataset = drug_dataset.map(
    lambda x: {
        "review": [html.unescape(o) for o in x["review"]]}, 
    	batched=True
)
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")


def tokenize_function(examples):
    return tokenizer(examples["review"], truncation=True)

# %time tokenized_dataset = drug_dataset.map(tokenize_function, batched=True)
# Out:
# Loading cached processed dataset at /home/kosenko/.cache/huggingface/datasets/csv/default-870720e81f127769/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-9aa7e94ae58c8352.arrow
# A Jupyter Widget
# CPU times: user 38.2 s, sys: 181 ms, total: 38.4 s
# Wall time: 5.21 s

# %%
# %time tokenized_dataset = drug_dataset.map(tokenize_function)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# CPU times: user 1min 45s, sys: 594 ms, total: 1min 46s
# Wall time: 1min 46s

# %%
# %time tokenized_dataset = drug_dataset.map(tokenize_function, batched=True)

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased", use_fast=False)

# %%
# спойлер очень медленно
# %time tokenized_dataset = drug_dataset.map(tokenize_function, batched=True)

# %%
slow_tokenizer = AutoTokenizer.from_pretrained("bert-base-cased", use_fast=False)


def slow_tokenize_function(examples):
    return slow_tokenizer(examples["review"], truncation=True)


tokenized_dataset = drug_dataset.map(slow_tokenize_function, batched=True, num_proc=8)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased", use_fast=True)


def slow_tokenize_function(examples):
    return tokenizer(examples["review"], truncation=True)


tokenized_dataset = drug_dataset.map(slow_tokenize_function, batched=True, num_proc=8)

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased", use_fast=True)

def tokenize_and_split(examples):
    return tokenizer(
        examples["review"],
        truncation=True,
        max_length=128,
        return_overflowing_tokens=True,
    )

result = tokenize_and_split(drug_dataset["train"][0])
[len(inp) for inp in result["input_ids"]]
# Out:
# [25]

# %%
tokenized_dataset = drug_dataset.map(tokenize_and_split, batched=True)
# Out:
# A Jupyter Widget
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In [49], line 1
# ----> 1 tokenized_dataset = drug_dataset.map(tokenize_and_split, batched=True)
#
# File ~/env/lib/python3.8/site-packages/datasets/dataset_dict.py:777, in map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     767 if cache_file_names is None:
#     768     cache_file_names = {k: None for k in self}
#     769 return DatasetDict(
#     770     {
#     771         k: dataset.map(
#     772             function=function,
#     773             with_indices=with_indices,
#     774             with_rank=with_rank,
#     775             input_columns=input_columns,
#     776             batched=batched,
# ...

# %%
tokenized_dataset = drug_dataset.map(
    tokenize_and_split, batched=True, 
    remove_columns=drug_dataset["train"].column_names
)
# Out:
# A Jupyter Widget
# A Jupyter Widget

# %%
def tokenize_and_split(examples):
    result = tokenizer(
        examples["review"],
        truncation=True,
        max_length=128,
        return_overflowing_tokens=True,
    )
    # Extract mapping between new and old indices
    sample_map = result.pop("overflow_to_sample_mapping")
    for key, values in examples.items():
        result[key] = [values[i] for i in sample_map]
    return result

tokenized_dataset = drug_dataset.map(tokenize_and_split, batched=True)
tokenized_dataset
# Out:
# A Jupyter Widget
# A Jupyter Widget
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 228656
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 76239
#     })
# })

# %%
drug_dataset.set_format("pandas")
drug_dataset["train"][:3]
# Out:
#    patient_id    drugName                     condition  \
# 0      206461   Valsartan  left ventricular dysfunction
# 1       95260  Guanfacine                          adhd
# 2       92703      Lybrel                 birth control
#
#                                               review  rating  \
# 0  "It has no side effect, I take it in combinati...     9.0
# 1  "My son is halfway through his fourth week of ...     8.0
# 2  "I used to take another oral contraceptive, wh...     5.0
#
#                 date  usefulCount  review_length
# 0       May 20, 2012           27             17
# 1     April 27, 2010          192            141
# 2  December 14, 2009           17            134

# %%
drug_dataset_clean = drug_dataset["train"].train_test_split(train_size=0.8, seed=42)
# Rename the default "test" split to "validation"
drug_dataset_clean["validation"] = drug_dataset_clean.pop("test")
# Add the "test" set to our `DatasetDict`
drug_dataset_clean["test"] = drug_dataset["test"]
drug_dataset_clean
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 128318
#     })
#     validation: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 32080
#     })
#     test: Dataset({
#         features: ['patient_id', 'drugName', 'condition', 'review', 'rating', 'date', 'usefulCount', 'review_length'],
#         num_rows: 53471
#     })
# })

# %% [markdown]
# # Big data? 🤗 Datasets to the rescue!

# %%
from datasets import load_dataset

# This takes a few minutes to run, so go grab a tea or coffee while you wait :)
data_files = "./datasets/it_squad/SQuAD_it-train.json.gz"
pubmed_dataset = load_dataset(
    "json", 
    data_files=data_files, 
    split="train",
	field="data"
)
pubmed_dataset
# Out:
# Using custom data configuration default-d929dc525182cb8e
# ...
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# Dataset json downloaded and prepared to /home/kosenko/.cache/huggingface/datasets/json/default-d929dc525182cb8e/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab. Subsequent calls will reuse this data.
# Dataset({
#     features: ['title', 'paragraphs'],
#     num_rows: 442
# })

# %%
import psutil

# Process.memory_info is expressed in bytes, so convert to megabytes
print(f"RAM used: {psutil.Process().memory_info().rss / (1024 * 1024):.2f} MB")
# Out:
# RAM used: 641.17 MB

# %%
print(f"Number of files in dataset : {pubmed_dataset.dataset_size}")
size_gb = pubmed_dataset.dataset_size / (1024**3)
print(f"Dataset size (cache file) : {size_gb:.2f} GB")
# Out:
# Number of files in dataset : 21663431
# Dataset size (cache file) : 0.02 GB

# %%
pubmed_dataset_streamed = load_dataset(
    "json", 
    data_files=data_files, 
    split="train", 
    streaming=True,
    field="data"
)
# Out:
# Using custom data configuration default-d929dc525182cb8e

# %%
next(iter(pubmed_dataset_streamed))
# Out:
# {'title': 'Terremoto del Sichuan del 2008',
#  'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
tokenized_dataset = pubmed_dataset_streamed.map(lambda x: tokenizer(x["title"]))
next(iter(tokenized_dataset))
# Out:
# {'title': 'Terremoto del Sichuan del 2008',
#  'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#     {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
#      'id': '56d4f9902ccc5a1400d833c1',
# ...

# %%
shuffled_dataset = pubmed_dataset_streamed.shuffle(buffer_size=10_000, seed=42)
next(iter(shuffled_dataset))
# Out:
# {'title': 'New Haven',
#  'paragraphs': [{'context': "New Haven (locale /nu? v? v? n/, noo-HAY-v? n), nello stato americano del Connecticut, è il principale comune di Greater New Haven, che nel 2010 aveva una popolazione totale di 862.477 abitanti. Si trova sul porto di New Haven Harbor sulla riva settentrionale del Long Island Sound nella contea di New Haven, Connecticut, che a sua volta comprende i limiti esterni dell' area metropolitana di New York. È la seconda città più grande del Connecticut (dopo Bridgeport), con una popolazione di 129.779 abitanti al censimento degli Stati Uniti del 2010. Secondo un censimento del 1 ° luglio 2012, da parte dell' Ufficio di censimento, la cittÃ\xa0 aveva una popolazione di 130.741 abitanti. Bridgeport.",
#    'qas': [{'answers': [{'answer_start': 455, 'text': 'Bridgeport'}],
#      'id': '572642ea89a1e219009ac623',
#      'question': 'Qual era la popolazione di New Haven secondo il censimento del 2012?'},
# ...

# %%
dataset_head = pubmed_dataset_streamed.take(5)
list(dataset_head)
# Out:
# [{'title': 'Terremoto del Sichuan del 2008',
#   'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#     'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#       'id': '56cdca7862d2951400fa6826',
#       'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#      {'answers': [{'answer_start': 232, 'text': '69.197'}],
#       'id': '56cdca7862d2951400fa6828',
#       'question': 'Quante persone sono state uccise come risultato?'},
#      {'answers': [{'answer_start': 29, 'text': '2008'}],
#       'id': '56d4f9902ccc5a1400d833c0',
#       'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#      {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
# ...

# %%
# Skip the first 1,000 examples and include the rest in the training set
train_dataset = shuffled_dataset.skip(1000)
# Take the first 1,000 examples for the validation set
validation_dataset = shuffled_dataset.take(1000)

# %%
law_dataset_streamed = load_dataset(
    "json",
    data_files="./datasets/it_squad/SQuAD_it-train.json.gz",
    split="train",
    streaming=True,
    field="data"
)
next(iter(law_dataset_streamed))
# Out:
# Using custom data configuration default-d929dc525182cb8e
# {'title': 'Terremoto del Sichuan del 2008',
#  'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#    'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56cdca7862d2951400fa6826',
#      'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#     {'answers': [{'answer_start': 232, 'text': '69.197'}],
#      'id': '56cdca7862d2951400fa6828',
#      'question': 'Quante persone sono state uccise come risultato?'},
#     {'answers': [{'answer_start': 29, 'text': '2008'}],
#      'id': '56d4f9902ccc5a1400d833c0',
#      'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
# ...

# %%
from itertools import islice
from datasets import interleave_datasets

combined_dataset = interleave_datasets([pubmed_dataset_streamed, law_dataset_streamed])
list(islice(combined_dataset, 2))
# Out:
# [{'title': 'Terremoto del Sichuan del 2008',
#   'paragraphs': [{'context': "Il terremoto del Sichuan del 2008 o il terremoto del Gran Sichuan, misurato a 8.0 Ms e 7.9 Mw, e si è verificato alle 02:28:01 PM China Standard Time all' epicentro (06:28:01 UTC) il 12 maggio nella provincia del Sichuan, ha ucciso 69.197 persone e lasciato 18.222 dispersi.",
#     'qas': [{'answers': [{'answer_start': 29, 'text': '2008'}],
#       'id': '56cdca7862d2951400fa6826',
#       'question': 'In quale anno si è verificato il terremoto nel Sichuan?'},
#      {'answers': [{'answer_start': 232, 'text': '69.197'}],
#       'id': '56cdca7862d2951400fa6828',
#       'question': 'Quante persone sono state uccise come risultato?'},
#      {'answers': [{'answer_start': 29, 'text': '2008'}],
#       'id': '56d4f9902ccc5a1400d833c0',
#       'question': 'Quale anno ha avuto luogo il terremoto del Sichuan?'},
#      {'answers': [{'answer_start': 78, 'text': '8.0 Ms e 7.9 Mw'}],
# ...
