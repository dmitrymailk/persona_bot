# %%
import peewee as pw

# %%
class BaseModel(pw.Model):
    class Meta:
        db = pw.PostgresqlDatabase(
            'nlp_database', 
            user='postgres', 
            password='postgres', 
            host='195.14.48.196', 
            port=2345,
            autorollback=True,
        )
        db.connect()
        database = db
        
        
class User(BaseModel):
    username = pw.CharField(unique=True)
    email = pw.CharField(unique=True)
    password = pw.CharField()

User.create_table()

# %%
import peewee as pw

db = pw.PostgresqlDatabase(
            'nlp_database', 
            user='postgres', 
            password='postgres', 
            host='195.14.48.196', 
            port=2345,
            autorollback=True,
        )
db.connect()
# Out:
# True

# %% [markdown]
# ### analize the database

# %%
from dimweb_persona_bot.database_logger.scripts.analize_database import DatabaseAnalyzerV1

db = DatabaseAnalyzerV1(
	host="195.14.48.196",
	port=2345,
)

# %%
db.get_random_sample_by_wandb_run_id(
	wandb_run_id="3fjokvrk",
	columns=[
		'wandb_run_id',
		'model_name',
		'epoch',
		'context',
		'model_prediction',
		'actual_response',
	]
)

# %%
db.get_sample_with_metrics_by_wandb_run_id(
	wandb_run_id="1j1z6he1",
 	samples_amount=10
)
# Out:
#   wandb_run_id model_name prediction_id  epoch  \
# 0     1j1z6he1       gpt2         238_4     -1
# 1     1j1z6he1       gpt2         238_4      0
# 2     1j1z6he1       gpt2         238_4      1
# 3     1j1z6he1       gpt2         238_4      2
# 0     1j1z6he1       gpt2         266_2     -1
# 1     1j1z6he1       gpt2         266_2      0
# 2     1j1z6he1       gpt2         266_2      1
# 3     1j1z6he1       gpt2         266_2      2
# 0     1j1z6he1       gpt2         416_4     -1
# 1     1j1z6he1       gpt2         416_4      0
# 2     1j1z6he1       gpt2         416_4      1
# 3     1j1z6he1       gpt2         416_4      2
# 0     1j1z6he1       gpt2          45_2     -1
# 1     1j1z6he1       gpt2          45_2      0
# 2     1j1z6he1       gpt2          45_2      1
# 3     1j1z6he1       gpt2          45_2      2
# 0     1j1z6he1       gpt2         269_1     -1
# 1     1j1z6he1       gpt2         269_1      0
# 2     1j1z6he1       gpt2         269_1      1
# 3     1j1z6he1       gpt2         269_1      2
# 0     1j1z6he1       gpt2          53_6     -1
# 1     1j1z6he1       gpt2          53_6      0
# 2     1j1z6he1       gpt2          53_6      1
# 3     1j1z6he1       gpt2          53_6      2
# 0     1j1z6he1       gpt2         336_6     -1
# 1     1j1z6he1       gpt2         336_6      0
# 2     1j1z6he1       gpt2         336_6      1
# 3     1j1z6he1       gpt2         336_6      2
# 0     1j1z6he1       gpt2         482_1     -1
# 1     1j1z6he1       gpt2         482_1      0
# 2     1j1z6he1       gpt2         482_1      1
# 3     1j1z6he1       gpt2         482_1      2
# 0     1j1z6he1       gpt2         252_5     -1
# 1     1j1z6he1       gpt2         252_5      0
# 2     1j1z6he1       gpt2         252_5      1
# 3     1j1z6he1       gpt2         252_5      2
# 0     1j1z6he1       gpt2         345_5     -1
# 1     1j1z6he1       gpt2         345_5      0
# 2     1j1z6he1       gpt2         345_5      1
# 3     1j1z6he1       gpt2         345_5      2
#
#                                              context  \
# 0  i waitress during the day to supplement my inc...
# 1  i waitress during the day to supplement my inc...
# 2  i waitress during the day to supplement my inc...
# 3  i waitress during the day to supplement my inc...
#                                      actual_response  valid_loss_epoch  \
# 0  oh nice. i grew up riding motorbikes with dad ...          3.695390
# 1  oh nice. i grew up riding motorbikes with dad ...          3.093047
# 2  oh nice. i grew up riding motorbikes with dad ...          3.210186
# 3  oh nice. i grew up riding motorbikes with dad ...          3.271263
# 0  what is wrong? my wife is a doctor if you need...          3.695390
# 1  what is wrong? my wife is a doctor if you need...          3.093047
# 2  what is wrong? my wife is a doctor if you need...          3.210186
# 3  what is wrong? my wife is a doctor if you need...          3.271263
# 0  i prefer horses over people! i love to ride, d...          3.695390
# 1  i prefer horses over people! i love to ride, d...          3.093047
# 2  i prefer horses over people! i love to ride, d...          3.210186
# 3  i prefer horses over people! i love to ride, d...          3.271263
# 0  ma. i was gonna finish a roof today. at least ...          3.695390
# 1  ma. i was gonna finish a roof today. at least ...          3.093047
# 2  ma. i was gonna finish a roof today. at least ...          3.210186
# 3  ma. i was gonna finish a roof today. at least ...          3.271263
# 0                 hello! i'm lonely. how about you?           3.695390
# 1                 hello! i'm lonely. how about you?           3.093047
# 2                 hello! i'm lonely. how about you?           3.210186
# 3                 hello! i'm lonely. how about you?           3.271263
# 0      i prefer soccer, but what music do you like?           3.695390
# 1      i prefer soccer, but what music do you like?           3.093047
# 2      i prefer soccer, but what music do you like?           3.210186
# 3      i prefer soccer, but what music do you like?           3.271263
# 0  vanilla is a favorite, real gelato is my weakn...          3.695390
# 1  vanilla is a favorite, real gelato is my weakn...          3.093047
# 2  vanilla is a favorite, real gelato is my weakn...          3.210186
# 3  vanilla is a favorite, real gelato is my weakn...          3.271263
# 0  i love ice cream what is your favorite? mine i...          3.695390
# 1  i love ice cream what is your favorite? mine i...          3.093047
# 2  i love ice cream what is your favorite? mine i...          3.210186
# 3  i love ice cream what is your favorite? mine i...          3.271263
# 0     that's a good thing to do. do they work well?           3.695390
# 1     that's a good thing to do. do they work well?           3.093047
# 2     that's a good thing to do. do they work well?           3.210186
# 3     that's a good thing to do. do they work well?           3.271263
# 0  what college team is your favorite? i like nor...          3.695390
# 1  what college team is your favorite? i like nor...          3.093047
# 2  what college team is your favorite? i like nor...          3.210186
# 3  what college team is your favorite? i like nor...          3.271263
#
#    blue_score_epoch  rougel_score_epoch  charf_score_epoch
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927
# 0          0.463528            0.082258           0.132706
# 1          1.206639            0.138508           0.131566
# 2          1.375699            0.140010           0.133709
# 3          1.405097            0.143313           0.133927

# %%
db.get_sample_with_metrics_by_wandb_run_id_and_sample_id(
	sample_ids=[
		'34_2',
	],
	wandb_run_ids=[
		"s5dp59fv",
  		"1goz6m2m",
    	"15or5dmk"
	]
)
# Out:
#   wandb_run_id                model_name prediction_id  epoch  \
# 0     s5dp59fv  RUCAIBox/mvp-open-dialog          34_2     -1
# 1     s5dp59fv  RUCAIBox/mvp-open-dialog          34_2      0
# 2     s5dp59fv  RUCAIBox/mvp-open-dialog          34_2      1
# 3     s5dp59fv  RUCAIBox/mvp-open-dialog          34_2      2
# 4     s5dp59fv  RUCAIBox/mvp-open-dialog          34_2      3
# 0     1goz6m2m        facebook/bart-base          34_2     -1
# 1     1goz6m2m        facebook/bart-base          34_2      0
# 2     1goz6m2m        facebook/bart-base          34_2      1
# 3     1goz6m2m        facebook/bart-base          34_2      2
# 4     1goz6m2m        facebook/bart-base          34_2      3
# 0     15or5dmk        facebook/bart-base          34_2     -1
# 1     15or5dmk        facebook/bart-base          34_2      0
# 2     15or5dmk        facebook/bart-base          34_2      1
# 3     15or5dmk        facebook/bart-base          34_2      2
# 4     15or5dmk        facebook/bart-base          34_2      3
#
#                                              context  \
# 0  i prefer being inside.i am a recording enginee...
# 1  i prefer being inside.i am a recording enginee...
# 2  i prefer being inside.i am a recording enginee...
# 3  i prefer being inside.i am a recording enginee...
# 4  i prefer being inside.i am a recording enginee...
# 0  i prefer being inside.i am a recording enginee...
# 1  i prefer being inside.i am a recording enginee...
# 2  i prefer being inside.i am a recording enginee...
# 3  i prefer being inside.i am a recording enginee...
# 4  i prefer being inside.i am a recording enginee...
# 0  i prefer being inside.i am a recording enginee...
# 1  i prefer being inside.i am a recording enginee...
# 2  i prefer being inside.i am a recording enginee...
# 3  i prefer being inside.i am a recording enginee...
# 4  i prefer being inside.i am a recording enginee...
#
#                                     model_prediction  \
# 0  i love donuts too. i like to eat them when i g...
# 1    i'm sorry to hear that. what do you do for fun?
# 2             that is cool. what do you do for work?
# 3                           do you have any hobbies?
# 4                 that's cool. do you have any pets?
# 0  i prefer being inside. i prefer being outside....
# 1           i like donuts too. do you have any kids?
# 2                              do you have any kids?
# 3           i like donuts but i prefer to be inside.
# 4           i like donuts too. do you have any kids?
# 0  i prefer being inside. I prefer being outside....
# 1     i am a 46 year old man who lives in california
# 2                              do you have any kids?
# 3          i live in california, where are you from?
# 4          i live in california, where are you from?
#
#                                      actual_response  valid_loss_epoch  \
# 0  i am actually a recording engineer. do you hav...          2.696478
# 1  i am actually a recording engineer. do you hav...          3.248337
# 2  i am actually a recording engineer. do you hav...          3.149744
# 3  i am actually a recording engineer. do you hav...          3.140317
# 4  i am actually a recording engineer. do you hav...          3.208448
# 0  i am actually a recording engineer. do you hav...          4.159739
# 1  i am actually a recording engineer. do you hav...          2.610327
# 2  i am actually a recording engineer. do you hav...          2.538346
# 3  i am actually a recording engineer. do you hav...          2.505171
# 4  i am actually a recording engineer. do you hav...          2.537550
# 0  i am actually a recording engineer. do you hav...          4.076736
# 1  i am actually a recording engineer. do you hav...          2.600129
# 2  i am actually a recording engineer. do you hav...          2.514609
# 3  i am actually a recording engineer. do you hav...          2.500678
# 4  i am actually a recording engineer. do you hav...          2.521952
#
#    blue_score_epoch  rougel_score_epoch  charf_score_epoch
# 0          2.340082            0.160500           0.138412
# 1          1.913758            0.142882           0.129488
# 2          2.073643            0.122784           0.125655
# 3          1.685845            0.114113           0.117123
# 4          1.964711            0.106125           0.116018
# 0          0.803446            0.086905           0.151757
# 1          3.413110            0.184983           0.155072
# 2          4.010461            0.193400           0.158206
# 3          4.331124            0.201090           0.169969
# 4          4.393390            0.199385           0.170634
# 0          0.623410            0.075485           0.126816
# 1          3.923617            0.190337           0.159001
# 2          4.179494            0.197099           0.162810
# 3          4.650367            0.205612           0.175553
# 4          4.824678            0.208625           0.178045

# %%
from dimweb_persona_bot.utils import TextEvaluator

ev = TextEvaluator()

ev.evaluate(
	generated_texts=["that's neat . when i was in high school i placed 6th in 100m dash"],
	original_texts=["that's neat . when i was in high school i placed 6th in 100m dash !"]
)
# Out:
# {'blue_score': 93.55069850316181,
#  'rougeL_score': 1.0,
#  'chrf_score': 0.974729061126709}

# %%
import wandb
api = wandb.Api()

run = api.run("dimweb/persona_bot_2/gljti7kh")
# if run.state == "finished":
#    for i, row in run.history(keys=["accuracy"]).iterrows():
#       print(row["accuracy"])
for item in run.history(keys=["valid_blue_score_epoch"]).iterrows():
   print(f'{item[0]} {item[1]["valid_blue_score_epoch"]}')
# Out:
# 0 0.4560723900794983
# 1 2.0392868518829346
# 2 1.8678674697875977
# 3 1.9170136451721191
